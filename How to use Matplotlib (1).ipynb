# %%
#Importing libraries

# %%
import matplotlib.pyplot as plt

# %%
#Lineal Plot

# %%
plt.figure(figsize=(10,7))

#Pais 1
x = [2016,2017,2018,2019,2020,2021]
y = [45, 46, 47, 48, 50, 51]


#Pais 2
x2= [2016,2017,2018,2019,2020,2021]
y2= [47,46,47, 49, 52, 53]


plt.plot(x,y,marker = "o", linestyle="--", color = "y", label="pais 1")
plt.plot(x2, y2, marker = "o", linestyle="--", color = "b", label="pais 2")

plt.xlabel("Años")
plt.ylabel("Población ( en millones)")
plt.title("Población por año")
plt.yticks([46,48,51])
plt.legend(loc="lower right")
plt.savefig("ejemplo.png")
plt.show()

# %%
# Subplot

# %%
fig, ax = plt.subplots(1,2, sharey=True)
ax[0].plot(x,y, color="g", label="pais 1")
ax[1].plot(x2,y2,color="b", label="pais 2")
plt.show()

# %%
# Bar Plots (Data categorica y data numérica)

# %%
x = ["Arg","Mex","Peru"]
y = [40,50,45]
plt.bar(x,y)
plt.show()

# %%
#Piecharts

# %%
plt.pie(y, labels=x) #Primer parametro numerico, el segundo, categorico.
plt.show()

# %%
#Histogramas

# %%
edades = [20,21,22,23,25,25,20,20,20,21,22,25,20,21,21,23,22,25,25,22]
bins=[20,21,22,23,24,25]
plt.hist(edades,bins,edgecolor="black")
plt.show()

# %%
#Boxplots

# %%
edades = [40,21,22,43,45,25,40,40,40,21,22,45,20,21,21,43,22,40, 25,25,22, 70]
plt.boxplot(edades)
plt.show()

# %%
#Scatterplot

# %%
a = [1,4,5,8,2,3,4,1]
b = [10,11,14,15,18,10,14,14]
plt.scatter(a,b)
plt.show()
